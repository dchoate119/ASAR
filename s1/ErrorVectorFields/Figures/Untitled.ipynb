# %%
import vtk
vtk.vtkObject.GlobalWarningDisplayOn()

from vedo import Plotter, Cube

cube = Cube()
plotter = Plotter()
plotter.show(cube, interactive=True)
# Out:
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 62
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 62
# pci id for fd 62: 8086:a7a0, driver iris
# MESA-LOADER: dlopen(/usr/lib/x86_64-linux-gnu/dri/iris_dri.so)
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# ...

# %%
# Out:
# /home/daniel-choate/miniconda3/envs/py39/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/daniel-choate/miniconda3/envs/py39/lib/python3.9/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 68
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 68
# pci id for fd 68: 8086:a7a0, driver iris
# MESA-LOADER: dlopen(/usr/lib/x86_64-linux-gnu/dri/iris_dri.so)
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# ...

# %%
# Out:
# /home/daniel-choate/miniconda3/envs/py39/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:37: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/daniel-choate/miniconda3/envs/py39/lib/python3.9/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 80
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 80
# pci id for fd 80: 8086:a7a0, driver iris
# MESA-LOADER: dlopen(/usr/lib/x86_64-linux-gnu/dri/iris_dri.so)
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# ...
