# %%
import vedo 
import ipyvtklink

from vedo import Plotter, Line

plotter = Plotter()
line = Line([0,0,0], [1,1,1])
plotter += line
plotter.show()

# %%
import matplotlib
matplotlib.use('TkAgg')  # Or 'Qt5Agg' or any other suitable backend

# %%
# %matplotlib notebook

# %%
from vedo import Plotter, Cube
from vedo.applications import Plotter as PlotterJupyter

cube = Cube()
plotter = PlotterJupyter()
plotter.show(cube, interactive=True)
# Out:
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 60
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# using driver i915 for 60
# pci id for fd 60: 8086:a7a0, driver iris
# MESA-LOADER: dlopen(/usr/lib/x86_64-linux-gnu/dri/iris_dri.so)
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# libGL: Can't open configuration file /home/daniel-choate/.drirc: No such file or directory.
# libGL: Can't open configuration file /etc/drirc: No such file or directory.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import vtk
#       2 from ipyvtklink.viewer import ViewInteractiveWidget
#       4 # Create some data
#
# File ~/miniconda3/envs/newenv/lib/python3.9/site-packages/vtk.py:30
#      28 import importlib
#      29 # import vtkmodules.all
# ---> 30 all_m = importlib.import_module('vtkmodules.all')
#      32 # import vtkmodules
#      33 vtkmodules_m = importlib.import_module('vtkmodules')
#
# File ~/miniconda3/envs/newenv/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniconda3/envs/newenv/lib/python3.9/site-packages/vtkmodules/all.py:54
#      52 from .vtkIOMovie import *
#      53 from .vtkIOOggTheora import *
# ...
